# %% [markdown]
# # EEG Data Processing and Analysis Pipeline for Neurofeedback Experiments
#
# ### Author: Michael Zhou (mgz2112)

# %%
import h5py
import numpy as np
import os
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt
from mne.preprocessing import ICA
from mne import create_info, EpochsArray
from mne.time_frequency import tfr_morlet
import gc
from joblib import Parallel, delayed
import pickle
import time
from tqdm import tqdm

# %% [markdown]
# ## 1. Loading and Visualizing EEG Data
#
# Load and analyze EEG data from multiple `.mat` files. Each file contains raw EEG signals collected from various neurofeedback VR flight experiments.
#
# 1. **Load EEG data**: Start by reading EEG data using the `h5py` library, which allows us to access and extract information from MATLAB `.mat` files. The EEG data is stored as a matrix where the rows represent different time points, and the columns represent channels.
# 2. **Reshape data**: To ensure consistency, we check the shape of the loaded data. If necessary, the data is transposed so that the format aligns with `(channels x time points)`. This reshaping standardizes the data for further analysis.
# 3. **Visualize data**: For initial exploration, we plot the first 1000 time points of two EEG channels. These plots provide a quick visual check of signal amplitude and variability, helping identify potential noise or artifacts.
# 4. **Event handling**: Alongside the EEG signals, each file contains event markers that denote specific experimental events (e.g., stimulus presentation or user responses). We extract and decode these events to analyze their types and corresponding time points. A sample of these events is printed to give a sense of the experimental context.
# 5. **Categorize data**: The files are divided into three experimental conditions: Baseline, Open Loop, and Closed Loop. This categorization allows us to systematically process and analyze data across different experimental phases.
#
# By loading and visualizing EEG data in this manner, we prepare the dataset for subsequent preprocessing and analysis steps, including filtering, epoch extraction, and artifact removal.

# %%
# Given extracted data
# Extract features PER ELECTRODE (alpha, beta, gamma, etc.) - (12, num_features=256) 
# Train classifer WITHIN SUBJECT (LOOCV)
# Results 

# Add downsampling  
# Add filters (Butterworth, Chebyshev, etc.) + ICA

# %%
# Define file paths for EEG categories

# # Baseline (RWEO) files
# baseline_files = [
#     'S01_B_RWEO_PreOL.mat', 'S01_D_RWEO_PstOL.mat'
#     # 'S01_E_RWEO_PreCL.mat', 'S01_G_RWEO_PstCL.mat'
# ]

# Open-Loop Calibration (OLoop) files
open_loop_files = ['S01_C_OLoop.mat']

# Closed-Loop Feedback (CLoop and Feedback conditions)
closed_loop_files = ['S01_F_CL_Sil_50_100.mat']

# Define the base directory (where the original data is located)
base_dir = 'Faller_et_al_2019_PNAS_EEG_Neurofeedback_VR_Flight/' 

# Define the output directory (where the saved variables will be located)
output_dir = 'processed_data/'

# %%
def load_and_analyze_eeg(file_path):
    with h5py.File(file_path, 'r') as f:
        # Access EEG data and display shape
        all_data = np.array(f['actualVariable']['EEG_full']['data'])
        eeg_data = all_data[:, :64]
        print(f"Loaded file: {file_path}")
        print(f"EEG Data Shape (Time Steps x Channels): {eeg_data.shape}")
        
        # Ensure data is correctly shaped as (channels, time_steps)
        if eeg_data.shape[1] == 64:  # If shape is (time_steps, channels)
            eeg_data = eeg_data.T  # Transpose to (channels, time_steps)
        
        print(f"Transposed EEG Data Shape (Channels x Time): {eeg_data.shape}")
        
        # Plot first two channels for a visual check
        plt.figure(figsize=(10, 5))
        plt.plot(eeg_data[:64, :], label='EEG Channels')
        plt.title(f"Sample EEG Data from {os.path.basename(file_path)}")
        plt.xlabel("Time Points")
        plt.ylabel("Amplitude")
        plt.legend()
        plt.show()

        del eeg_data  # Free memory after processing
        gc.collect()
        
        # Correct event markers handling
        events = f['actualVariable']['EEG_full']['event']
        event_labels = []
        
        for i in range(len(events['type'])):
            # Dereference 'type' and 'latency' using h5py
            event_type_ref = events['type'][i][0]
            event_latency_ref = events['latency'][i][0]
            
            # Read the referenced data
            event_type = ''.join(chr(x) for x in f[event_type_ref][:].flatten())
            event_latency = f[event_latency_ref][()][0]
            event_labels.append((event_type, event_latency))
        
        print(f"Sample Event Labels from {os.path.basename(file_path)}:")
        for event in event_labels: 
            print(f"Type: {event[0]}, Latency: {event[1]}")

# Run analysis on each category
for category, file_list in [('Open Loop', open_loop_files)]:
    print(f"\n--- {category} Files Analysis ---")
    for file_name in file_list:
        full_path = os.path.join(base_dir, file_name)
        load_and_analyze_eeg(full_path)
# Out:
# --- Open Loop Files Analysis ---
# Loaded file: Faller_et_al_2019_PNAS_EEG_Neurofeedback_VR_Flight/S01_C_OLoop.mat
# EEG Data Shape (Time Steps x Channels): (139536, 64)
# Transposed EEG Data Shape (Channels x Time): (64, 139536)
# /Users/michaelzhou/miniforge3/envs/tf_m1/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniforge3/envs/tf_m1/lib/python3.8/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/miniforge3/envs/tf_m1/lib/python3.8/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/miniforge3/envs/tf_m1/lib/python3.8/site-packages/matplotlib/backend_bases.py:2366, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2362 try:
#    2363     # _get_renderer may change the figure dpi (as vector formats
#    2364     # force the figure dpi to 72), so we need to set it again here.
#    2365     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366         result = print_method(
#    2367             filename,
#    2368             facecolor=facecolor,
#    2369             edgecolor=edgecolor,
#    2370             orientation=orientation,
#    2371             bbox_inches_restore=_bbox_inches_restore,
#    2372             **kwargs)
#    2373 finally:
#    2374     if bbox_inches and restore_bbox:
#
# File ~/miniforge3/envs/tf_m1/lib/python3.8/site-packages/matplotlib/backend_bases.py:2232, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2228     optional_kws = {  # Passed by print_figure for other renderers.
#    2229         "dpi", "facecolor", "edgecolor", "orientation",
#    2230         "bbox_inches_restore"}
#    2231     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234 else:  # Let third-parties do as they see fit.
#    2235     print_method = meth
#
# File ~/miniforge3/envs/tf_m1/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:509, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     462 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     463     """
#     464     Write the figure to a PNG file.
#     465
#    (...)
#     507         *metadata*, including the default 'Software' key.
#     508     """
# --> 509     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/miniforge3/envs/tf_m1/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:457, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     452 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     453     """
#     454     Draw the canvas, then save it using `.image.imsave` (to which
#     455     *pil_kwargs* and *metadata* are forwarded).
#     456     """
# --> 457     FigureCanvasAgg.draw(self)
#     458     mpl.image.imsave(
#     459         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/miniforge3/envs/tf_m1/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:394, in FigureCanvasAgg.draw(self)
#     392 def draw(self):
#     393     # docstring inherited
# --> 394     self.renderer = self.get_renderer()
#     395     self.renderer.clear()
#     396     # Acquire a lock on the shared font cache.
#
# File ~/miniforge3/envs/tf_m1/lib/python3.8/site-packages/matplotlib/_api/deprecation.py:384, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     379 @functools.wraps(func)
#     380 def wrapper(*inner_args, **inner_kwargs):
#     381     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     382         # Early return in the simple, non-deprecated case (much faster than
#     383         # calling bind()).
# --> 384         return func(*inner_args, **inner_kwargs)
#     385     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     386     if is_varargs and arguments.get(name):
#
# File ~/miniforge3/envs/tf_m1/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:411, in FigureCanvasAgg.get_renderer(self, cleared)
#     409 reuse_renderer = (self._lastKey == key)
#     410 if not reuse_renderer:
# --> 411     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     412     self._lastKey = key
#     413 elif cleared:
#
# File ~/miniforge3/envs/tf_m1/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:84, in RendererAgg.__init__(self, width, height, dpi)
#      82 self.width = width
#      83 self.height = height
# ---> 84 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      85 self._filter_renderers = []
#      87 self._update_methods()
#
# ValueError: Image size of 853x2922555 pixels is too large. It must be less than 2^16 in each direction.
# Sample Event Labels from S01_C_OLoop.mat:
# Type: EBlnk-Int-On, Latency: [1.]
# Type: EBlnk-On, Latency: [1.]
# Type: EBlnk-Off, Latency: [51.]
# Type: EBlnk-Int-On, Latency: [174.]
# Type: EBlnk-Int-Off, Latency: [179.]
# Type: EBlnk-On, Latency: [302.]
# Type: EBlnk-Off, Latency: [354.]
# Type: EBlnk-Int-On, Latency: [355.]
# Type: QRS, Latency: [465.]
# Type: QRS-C_OLoop, Latency: [465.]
# Type: EBlnk-Int-Off, Latency: [482.]
# Type: EBlnk-On, Latency: [483.]
# Type: EBlnk-Off, Latency: [515.]
# Type: EBlnk-Int-Off, Latency: [643.]
# Type: QRS, Latency: [708.]
# Type: QRS-C_OLoop, Latency: [708.]
# Type: START-C_OLoop, Latency: [771.044]
# Type: START-C_OLoop-LEN-66442, Latency: [771.044]
# Type: START-C_OLoop-Crs-Easy-Cnd-0-LEN-66442, Latency: [771.044]
# Type: QRS, Latency: [970.]
# Type: QRS-C_OLoop, Latency: [970.]
# Type: RingBound_Large, Latency: [1016.083]
# Type: Start_108_Cond_0, Latency: [1016.567]
# Type: StickMvmtPitch_All, Latency: [1023.511]
# Type: StickMvmtPitch_Size_108, Latency: [1024.117]
# Type: RingPassed_Size_108, Latency: [1025.083]
# Type: RingPassed_Size_108_Cond_0, Latency: [1025.567]
# Type: RingPassed_Cond_0, Latency: [1026.044]
# Type: ECG-RingPassed_Size_108, Latency: [1236.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [1236.]
# Type: ECG-RingPassed_Cond_0, Latency: [1236.]
# Type: QRS, Latency: [1236.]
# Type: QRS-C_OLoop, Latency: [1236.]
# Type: StickMvmtPitch_All, Latency: [1422.806]
# Type: StickMvmtPitch_Size_108, Latency: [1423.311]
# Type: ECG-RingPassed_Size_108, Latency: [1496.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [1496.]
# Type: ECG-RingPassed_Cond_0, Latency: [1496.]
# Type: QRS, Latency: [1496.]
# Type: QRS-C_OLoop, Latency: [1496.]
# Type: RingPassed_Size_108, Latency: [1535.497]
# Type: RingPassed_Size_108_Cond_0, Latency: [1535.995]
# Type: RingPassed_Cond_0, Latency: [1536.484]
# Type: ECG-RingPassed_Size_108, Latency: [1763.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [1763.]
# Type: ECG-RingPassed_Cond_0, Latency: [1763.]
# Type: QRS, Latency: [1763.]
# Type: QRS-C_OLoop, Latency: [1763.]
# Type: ECG-RingPassed_Size_108, Latency: [2036.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [2036.]
# Type: ECG-RingPassed_Cond_0, Latency: [2036.]
# Type: QRS, Latency: [2036.]
# Type: QRS-C_OLoop, Latency: [2036.]
# Type: RingPassed_Size_108, Latency: [2047.509]
# Type: RingPassed_Size_108_Cond_0, Latency: [2048.082]
# Type: RingPassed_Cond_0, Latency: [2048.59]
# Type: ECG-RingPassed_Size_108, Latency: [2304.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [2304.]
# Type: ECG-RingPassed_Cond_0, Latency: [2304.]
# Type: QRS, Latency: [2304.]
# Type: QRS-C_OLoop, Latency: [2304.]
# Type: EBlnk-Int-On, Latency: [2355.]
# Type: StickMvmtPitch_All, Latency: [2412.453]
# Type: StickMvmtPitch_Size_108, Latency: [2412.959]
# Type: EBlnk-On, Latency: [2483.]
# Type: EBlnk-Off, Latency: [2500.]
# Type: RingPassed_Size_108, Latency: [2562.834]
# Type: RingPassed_Size_108_Cond_0, Latency: [2563.336]
# Type: RingPassed_Cond_0, Latency: [2563.819]
# Type: ECG-RingPassed_Size_108, Latency: [2571.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [2571.]
# Type: ECG-RingPassed_Cond_0, Latency: [2571.]
# Type: QRS, Latency: [2571.]
# Type: QRS-C_OLoop, Latency: [2571.]
# Type: EBlnk-Int-Off, Latency: [2628.]
# Type: ECG-RingPassed_Size_108, Latency: [2819.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [2819.]
# Type: ECG-RingPassed_Cond_0, Latency: [2819.]
# Type: QRS, Latency: [2819.]
# Type: QRS-C_OLoop, Latency: [2819.]
# Type: EBlnk-Int-On, Latency: [2973.]
# Type: ECG-RingPassed_Size_108, Latency: [3049.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [3049.]
# Type: ECG-RingPassed_Cond_0, Latency: [3049.]
# Type: QRS, Latency: [3049.]
# Type: QRS-C_OLoop, Latency: [3049.]
# Type: RingPassed_Size_108, Latency: [3074.83]
# Type: RingPassed_Size_108_Cond_0, Latency: [3075.333]
# Type: RingPassed_Cond_0, Latency: [3075.82]
# Type: EBlnk-On, Latency: [3101.]
# Type: EBlnk-Off, Latency: [3118.]
# Type: StickMvmtPitch_All, Latency: [3183.941]
# Type: StickMvmtPitch_Size_108, Latency: [3184.442]
# Type: EBlnk-Int-Off, Latency: [3246.]
# Type: ECG-RingPassed_Size_108, Latency: [3289.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [3289.]
# Type: ECG-RingPassed_Cond_0, Latency: [3289.]
# Type: QRS, Latency: [3289.]
# Type: QRS-C_OLoop, Latency: [3289.]
# Type: ECG-RingPassed_Size_108, Latency: [3534.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [3534.]
# Type: ECG-RingPassed_Cond_0, Latency: [3534.]
# Type: QRS, Latency: [3534.]
# Type: QRS-C_OLoop, Latency: [3534.]
# Type: RingPassed_Size_108, Latency: [3590.058]
# Type: RingPassed_Size_108_Cond_0, Latency: [3590.634]
# Type: RingPassed_Cond_0, Latency: [3591.141]
# Type: ECG-RingPassed_Size_108, Latency: [3804.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [3804.]
# Type: ECG-RingPassed_Cond_0, Latency: [3804.]
# Type: QRS, Latency: [3804.]
# Type: QRS-C_OLoop, Latency: [3804.]
# Type: StickMvmtPitch_All, Latency: [3914.357]
# Type: StickMvmtPitch_Size_108, Latency: [3914.86]
# Type: ECG-RingPassed_Size_108, Latency: [4087.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [4087.]
# Type: ECG-RingPassed_Cond_0, Latency: [4087.]
# Type: QRS, Latency: [4087.]
# Type: QRS-C_OLoop, Latency: [4087.]
# Type: RingPassed_Size_108, Latency: [4101.98]
# Type: RingPassed_Size_108_Cond_0, Latency: [4102.494]
# Type: RingPassed_Cond_0, Latency: [4102.985]
# Type: StickMvmtPitch_All, Latency: [4204.286]
# Type: StickMvmtPitch_Size_108, Latency: [4204.802]
# Type: ECG-RingPassed_Size_108, Latency: [4355.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [4355.]
# Type: ECG-RingPassed_Cond_0, Latency: [4355.]
# Type: QRS, Latency: [4355.]
# Type: QRS-C_OLoop, Latency: [4355.]
# Type: EBlnk-Int-On, Latency: [4421.]
# Type: EBlnk-On, Latency: [4549.]
# Type: EBlnk-Off, Latency: [4574.]
# Type: ECG-RingPassed_Size_108, Latency: [4617.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [4617.]
# Type: ECG-RingPassed_Cond_0, Latency: [4617.]
# Type: QRS, Latency: [4617.]
# Type: QRS-C_OLoop, Latency: [4617.]
# Type: RingPassed_Size_108, Latency: [4617.49]
# Type: RingPassed_Size_108_Cond_0, Latency: [4618.007]
# Type: RingPassed_Cond_0, Latency: [4618.508]
# Type: StickMvmtPitch_All, Latency: [4685.541]
# Type: StickMvmtPitch_Size_108, Latency: [4686.057]
# Type: EBlnk-Int-Off, Latency: [4702.]
# Type: ECG-RingPassed_Size_108, Latency: [4886.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [4886.]
# Type: ECG-RingPassed_Cond_0, Latency: [4886.]
# Type: QRS, Latency: [4886.]
# Type: QRS-C_OLoop, Latency: [4886.]
# Type: StickMvmtPitch_All, Latency: [4999.714]
# Type: StickMvmtPitch_Size_108, Latency: [5000.215]
# Type: RingPassed_Size_108, Latency: [5129.57]
# Type: RingPassed_Size_108_Cond_0, Latency: [5130.122]
# Type: RingPassed_Cond_0, Latency: [5130.64]
# Type: ECG-RingPassed_Size_108, Latency: [5147.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [5147.]
# Type: ECG-RingPassed_Cond_0, Latency: [5147.]
# Type: QRS, Latency: [5147.]
# Type: QRS-C_OLoop, Latency: [5147.]
# Type: ECG-RingPassed_Size_108, Latency: [5417.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [5417.]
# Type: ECG-RingPassed_Cond_0, Latency: [5417.]
# Type: QRS, Latency: [5417.]
# Type: QRS-C_OLoop, Latency: [5417.]
# Type: StickMvmtPitch_All, Latency: [5443.241]
# Type: StickMvmtPitch_Size_108, Latency: [5443.745]
# Type: RingPassed_Size_108, Latency: [5644.88]
# Type: RingPassed_Size_108_Cond_0, Latency: [5645.394]
# Type: RingPassed_Cond_0, Latency: [5645.882]
# Type: ECG-RingPassed_Size_108, Latency: [5676.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [5676.]
# Type: ECG-RingPassed_Cond_0, Latency: [5676.]
# Type: QRS, Latency: [5676.]
# Type: QRS-C_OLoop, Latency: [5676.]
# Type: StickMvmtPitch_All, Latency: [5825.684]
# Type: StickMvmtPitch_Size_108, Latency: [5826.188]
# Type: ECG-RingPassed_Size_108, Latency: [5943.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [5943.]
# Type: ECG-RingPassed_Cond_0, Latency: [5943.]
# Type: QRS, Latency: [5943.]
# Type: QRS-C_OLoop, Latency: [5943.]
# Type: EBlnk-Int-On, Latency: [5958.]
# Type: EBlnk-On, Latency: [6086.]
# Type: EBlnk-Off, Latency: [6116.]
# Type: RingPassed_Size_108, Latency: [6163.642]
# Type: RingPassed_Size_108_Cond_0, Latency: [6164.158]
# Type: RingPassed_Cond_0, Latency: [6164.647]
# Type: ECG-RingPassed_Size_108, Latency: [6204.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [6204.]
# Type: ECG-RingPassed_Cond_0, Latency: [6204.]
# Type: QRS, Latency: [6204.]
# Type: QRS-C_OLoop, Latency: [6204.]
# Type: EBlnk-Int-Off, Latency: [6244.]
# Type: ECG-RingPassed_Size_108, Latency: [6442.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [6442.]
# Type: ECG-RingPassed_Cond_0, Latency: [6442.]
# Type: QRS, Latency: [6442.]
# Type: QRS-C_OLoop, Latency: [6442.]
# Type: RingPassed_Size_108, Latency: [6679.011]
# Type: RingPassed_Size_108_Cond_0, Latency: [6679.531]
# Type: RingPassed_Cond_0, Latency: [6680.018]
# Type: ECG-RingPassed_Size_108, Latency: [6687.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [6687.]
# Type: ECG-RingPassed_Cond_0, Latency: [6687.]
# Type: QRS, Latency: [6687.]
# Type: QRS-C_OLoop, Latency: [6687.]
# Type: StickMvmtPitch_All, Latency: [6689.207]
# Type: StickMvmtPitch_Size_108, Latency: [6689.706]
# Type: StickMvmtPitch_All, Latency: [6784.601]
# Type: StickMvmtPitch_Size_108, Latency: [6785.106]
# Type: EBlnk-Int-On, Latency: [6823.]
# Type: ECG-RingPassed_Size_108, Latency: [6921.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [6921.]
# Type: ECG-RingPassed_Cond_0, Latency: [6921.]
# Type: QRS, Latency: [6921.]
# Type: QRS-C_OLoop, Latency: [6921.]
# Type: EBlnk-On, Latency: [6951.]
# Type: EBlnk-Off, Latency: [6972.]
# Type: StickMvmtPitch_All, Latency: [7050.862]
# Type: StickMvmtPitch_Size_108, Latency: [7051.377]
# Type: EBlnk-Int-Off, Latency: [7100.]
# Type: ECG-RingPassed_Size_108, Latency: [7167.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [7167.]
# Type: ECG-RingPassed_Cond_0, Latency: [7167.]
# Type: QRS, Latency: [7167.]
# Type: QRS-C_OLoop, Latency: [7167.]
# Type: RingPassed_Size_108, Latency: [7194.24]
# Type: RingPassed_Size_108_Cond_0, Latency: [7194.754]
# Type: RingPassed_Cond_0, Latency: [7195.241]
# Type: ECG-RingPassed_Size_108, Latency: [7418.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [7418.]
# Type: ECG-RingPassed_Cond_0, Latency: [7418.]
# Type: QRS, Latency: [7418.]
# Type: QRS-C_OLoop, Latency: [7418.]
# Type: StickMvmtPitch_All, Latency: [7586.843]
# Type: StickMvmtPitch_Size_108, Latency: [7587.349]
# Type: ECG-RingPassed_Size_108, Latency: [7661.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [7661.]
# Type: ECG-RingPassed_Cond_0, Latency: [7661.]
# Type: QRS, Latency: [7661.]
# Type: QRS-C_OLoop, Latency: [7661.]
# Type: RingPassed_Size_108, Latency: [7706.229]
# Type: RingPassed_Size_108_Cond_0, Latency: [7706.733]
# Type: RingPassed_Cond_0, Latency: [7707.218]
# Type: ECG-RingPassed_Size_108, Latency: [7914.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [7914.]
# Type: ECG-RingPassed_Cond_0, Latency: [7914.]
# Type: QRS, Latency: [7914.]
# Type: QRS-C_OLoop, Latency: [7914.]
# Type: StickMvmtPitch_All, Latency: [7938.483]
# Type: StickMvmtPitch_Size_108, Latency: [7939.038]
# Type: ECG-RingPassed_Size_108, Latency: [8158.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [8158.]
# Type: ECG-RingPassed_Cond_0, Latency: [8158.]
# Type: QRS, Latency: [8158.]
# Type: QRS-C_OLoop, Latency: [8158.]
# Type: RingPassed_Size_108, Latency: [8218.21]
# Type: RingPassed_Size_108_Cond_0, Latency: [8218.723]
# Type: RingPassed_Cond_0, Latency: [8219.219]
# Type: ECG-RingPassed_Size_108, Latency: [8409.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [8409.]
# Type: ECG-RingPassed_Cond_0, Latency: [8409.]
# Type: QRS, Latency: [8409.]
# Type: QRS-C_OLoop, Latency: [8409.]
# Type: StickMvmtPitch_All, Latency: [8556.016]
# Type: StickMvmtPitch_Size_72, Latency: [8556.525]
# Type: ECG-RingPassed_Size_108, Latency: [8665.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [8665.]
# Type: ECG-RingPassed_Cond_0, Latency: [8665.]
# Type: QRS, Latency: [8665.]
# Type: QRS-C_OLoop, Latency: [8665.]
# Type: StickMvmtPitch_All, Latency: [8675.625]
# Type: StickMvmtPitch_Size_72, Latency: [8676.128]
# Type: RingBound_Medium, Latency: [8724.716]
# Type: RingPassed_Size_72, Latency: [8733.716]
# Type: RingPassed_Size_72_Cond_0, Latency: [8734.222]
# Type: RingPassed_Cond_0, Latency: [8734.707]
# Type: ECG-RingPassed_Size_72, Latency: [8904.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [8904.]
# Type: ECG-RingPassed_Cond_0, Latency: [8904.]
# Type: QRS, Latency: [8904.]
# Type: QRS-C_OLoop, Latency: [8904.]
# Type: StickMvmtPitch_All, Latency: [9067.959]
# Type: StickMvmtPitch_Size_72, Latency: [9068.473]
# Type: ECG-RingPassed_Size_72, Latency: [9148.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [9148.]
# Type: ECG-RingPassed_Cond_0, Latency: [9148.]
# Type: QRS, Latency: [9148.]
# Type: QRS-C_OLoop, Latency: [9148.]
# Type: RingPassed_Size_72, Latency: [9249.09]
# Type: RingPassed_Size_72_Cond_0, Latency: [9249.611]
# Type: RingPassed_Cond_0, Latency: [9250.089]
# Type: ECG-RingPassed_Size_72, Latency: [9380.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [9380.]
# Type: ECG-RingPassed_Cond_0, Latency: [9380.]
# Type: QRS, Latency: [9380.]
# Type: QRS-C_OLoop, Latency: [9380.]
# Type: StickMvmtPitch_All, Latency: [9556.327]
# Type: StickMvmtPitch_Size_72, Latency: [9556.829]
# Type: EBlnk-Int-On, Latency: [9604.]
# Type: ECG-RingPassed_Size_72, Latency: [9618.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [9618.]
# Type: ECG-RingPassed_Cond_0, Latency: [9618.]
# Type: QRS, Latency: [9618.]
# Type: QRS-C_OLoop, Latency: [9618.]
# Type: EBlnk-On, Latency: [9732.]
# Type: EBlnk-Off, Latency: [9754.]
# Type: RingPassed_Size_72, Latency: [9764.326]
# Type: RingPassed_Size_72_Cond_0, Latency: [9764.836]
# Type: RingPassed_Cond_0, Latency: [9765.327]
# Type: ECG-RingPassed_Size_72, Latency: [9857.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [9857.]
# Type: ECG-RingPassed_Cond_0, Latency: [9857.]
# Type: QRS, Latency: [9857.]
# Type: QRS-C_OLoop, Latency: [9857.]
# Type: EBlnk-Int-Off, Latency: [9882.]
# Type: StickMvmtPitch_All, Latency: [9945.256]
# Type: StickMvmtPitch_Size_72, Latency: [9945.757]
# Type: ECG-RingPassed_Size_72, Latency: [10076.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [10076.]
# Type: ECG-RingPassed_Cond_0, Latency: [10076.]
# Type: QRS, Latency: [10076.]
# Type: QRS-C_OLoop, Latency: [10076.]
# Type: RingPassed_Size_72, Latency: [10276.293]
# Type: RingPassed_Size_72_Cond_0, Latency: [10276.831]
# Type: RingPassed_Cond_0, Latency: [10277.334]
# Type: ECG-RingPassed_Size_72, Latency: [10304.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [10304.]
# Type: ECG-RingPassed_Cond_0, Latency: [10304.]
# Type: QRS, Latency: [10304.]
# Type: QRS-C_OLoop, Latency: [10304.]
# Type: StickMvmtPitch_All, Latency: [10460.504]
# Type: StickMvmtPitch_Size_72, Latency: [10461.014]
# Type: ECG-RingPassed_Size_72, Latency: [10533.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [10533.]
# Type: ECG-RingPassed_Cond_0, Latency: [10533.]
# Type: QRS, Latency: [10533.]
# Type: QRS-C_OLoop, Latency: [10533.]
# Type: ECG-RingPassed_Size_72, Latency: [10750.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [10750.]
# Type: ECG-RingPassed_Cond_0, Latency: [10750.]
# Type: QRS, Latency: [10750.]
# Type: QRS-C_OLoop, Latency: [10750.]
# Type: RingPassed_Size_72, Latency: [10795.213]
# Type: RingPassed_Size_72_Cond_0, Latency: [10795.735]
# Type: RingPassed_Cond_0, Latency: [10796.235]
# Type: ECG-RingPassed_Size_72, Latency: [10970.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [10970.]
# Type: ECG-RingPassed_Cond_0, Latency: [10970.]
# Type: QRS, Latency: [10970.]
# Type: QRS-C_OLoop, Latency: [10970.]
# Type: StickMvmtPitch_All, Latency: [11030.918]
# Type: StickMvmtPitch_Size_72, Latency: [11031.421]
# Type: ECG-RingPassed_Size_72, Latency: [11191.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [11191.]
# Type: ECG-RingPassed_Cond_0, Latency: [11191.]
# Type: QRS, Latency: [11191.]
# Type: QRS-C_OLoop, Latency: [11191.]
# Type: RingPassed_Size_72, Latency: [11307.187]
# Type: RingPassed_Size_72_Cond_0, Latency: [11307.687]
# Type: RingPassed_Cond_0, Latency: [11308.173]
# Type: StickMvmtPitch_All, Latency: [11365.113]
# Type: StickMvmtPitch_Size_72, Latency: [11365.619]
# Type: ECG-RingPassed_Size_72, Latency: [11408.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [11408.]
# Type: ECG-RingPassed_Cond_0, Latency: [11408.]
# Type: QRS, Latency: [11408.]
# Type: QRS-C_OLoop, Latency: [11408.]
# Type: ECG-RingPassed_Size_72, Latency: [11637.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [11637.]
# Type: ECG-RingPassed_Cond_0, Latency: [11637.]
# Type: QRS, Latency: [11637.]
# Type: QRS-C_OLoop, Latency: [11637.]
# Type: StickMvmtPitch_All, Latency: [11692.775]
# Type: StickMvmtPitch_Size_72, Latency: [11693.277]
# Type: RingPassed_Size_72, Latency: [11822.419]
# Type: RingPassed_Size_72_Cond_0, Latency: [11822.928]
# Type: RingPassed_Cond_0, Latency: [11823.412]
# Type: ECG-RingPassed_Size_72, Latency: [11861.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [11861.]
# Type: ECG-RingPassed_Cond_0, Latency: [11861.]
# Type: QRS, Latency: [11861.]
# Type: QRS-C_OLoop, Latency: [11861.]
# Type: ECG-RingPassed_Size_72, Latency: [12086.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [12086.]
# Type: ECG-RingPassed_Cond_0, Latency: [12086.]
# Type: QRS, Latency: [12086.]
# Type: QRS-C_OLoop, Latency: [12086.]
# Type: StickMvmtPitch_All, Latency: [12150.011]
# Type: StickMvmtPitch_Size_72, Latency: [12150.528]
# Type: ECG-RingPassed_Size_72, Latency: [12314.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [12314.]
# Type: ECG-RingPassed_Cond_0, Latency: [12314.]
# Type: QRS, Latency: [12314.]
# Type: QRS-C_OLoop, Latency: [12314.]
# Type: RingPassed_Size_72, Latency: [12334.367]
# Type: RingPassed_Size_72_Cond_0, Latency: [12334.873]
# Type: RingPassed_Cond_0, Latency: [12335.367]
# Type: StickMvmtPitch_All, Latency: [12494.864]
# Type: StickMvmtPitch_Size_72, Latency: [12495.376]
# Type: ECG-RingPassed_Size_72, Latency: [12534.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [12534.]
# Type: ECG-RingPassed_Cond_0, Latency: [12534.]
# Type: QRS, Latency: [12534.]
# Type: QRS-C_OLoop, Latency: [12534.]
# Type: StickMvmtPitch_All, Latency: [12590.265]
# Type: StickMvmtPitch_Size_72, Latency: [12590.778]
# Type: ECG-RingPassed_Size_72, Latency: [12745.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [12745.]
# Type: ECG-RingPassed_Cond_0, Latency: [12745.]
# Type: QRS, Latency: [12745.]
# Type: QRS-C_OLoop, Latency: [12745.]
# Type: RingPassed_Size_72, Latency: [12850.165]
# Type: RingPassed_Size_72_Cond_0, Latency: [12850.674]
# Type: RingPassed_Cond_0, Latency: [12851.171]
# Type: ECG-RingPassed_Size_72, Latency: [12960.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [12960.]
# Type: ECG-RingPassed_Cond_0, Latency: [12960.]
# Type: QRS, Latency: [12960.]
# Type: QRS-C_OLoop, Latency: [12960.]
# Type: StickMvmtPitch_All, Latency: [12996.601]
# Type: StickMvmtPitch_Size_72, Latency: [12997.123]
# Type: EBlnk-Int-On, Latency: [13135.]
# Type: ECG-RingPassed_Size_72, Latency: [13166.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [13166.]
# Type: ECG-RingPassed_Cond_0, Latency: [13166.]
# Type: QRS, Latency: [13166.]
# Type: QRS-C_OLoop, Latency: [13166.]
# Type: StickMvmtPitch_All, Latency: [13225.418]
# Type: StickMvmtPitch_Size_72, Latency: [13225.935]
# Type: EBlnk-On, Latency: [13263.]
# Type: EBlnk-Off, Latency: [13272.]
# Type: ECG-RingPassed_Size_72, Latency: [13373.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [13373.]
# Type: ECG-RingPassed_Cond_0, Latency: [13373.]
# Type: QRS, Latency: [13373.]
# Type: QRS-C_OLoop, Latency: [13373.]
# Type: StickMvmtPitch_All, Latency: [13375.497]
# Type: StickMvmtPitch_Size_72, Latency: [13376.013]
# Type: RingPassed_Size_72, Latency: [13376.803]
# Type: RingPassed_Size_72_Cond_0, Latency: [13377.28]
# Type: RingPassed_Cond_0, Latency: [13377.757]
# Type: EBlnk-Int-Off, Latency: [13400.]
# Type: ECG-RingPassed_Size_72, Latency: [13582.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [13582.]
# Type: ECG-RingPassed_Cond_0, Latency: [13582.]
# Type: QRS, Latency: [13582.]
# Type: QRS-C_OLoop, Latency: [13582.]
# Type: ECG-RingPassed_Size_72, Latency: [13787.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [13787.]
# Type: ECG-RingPassed_Cond_0, Latency: [13787.]
# Type: QRS, Latency: [13787.]
# Type: QRS-C_OLoop, Latency: [13787.]
# Type: RingPassed_Size_72, Latency: [13890.753]
# Type: RingPassed_Size_72_Cond_0, Latency: [13891.266]
# Type: RingPassed_Cond_0, Latency: [13891.935]
# Type: StickMvmtPitch_All, Latency: [13969.338]
# Type: StickMvmtPitch_Size_72, Latency: [13969.839]
# Type: ECG-RingPassed_Size_72, Latency: [14004.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [14004.]
# Type: ECG-RingPassed_Cond_0, Latency: [14004.]
# Type: QRS, Latency: [14004.]
# Type: QRS-C_OLoop, Latency: [14004.]
# Type: ECG-RingPassed_Size_72, Latency: [14218.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [14218.]
# Type: ECG-RingPassed_Cond_0, Latency: [14218.]
# Type: QRS, Latency: [14218.]
# Type: QRS-C_OLoop, Latency: [14218.]
# Type: StickMvmtPitch_All, Latency: [14256.029]
# Type: StickMvmtPitch_Size_72, Latency: [14256.546]
# Type: EBlnk-Int-On, Latency: [14277.]
# Type: EBlnk-On, Latency: [14405.]
# Type: RingPassed_Size_72, Latency: [14406.56]
# Type: RingPassed_Size_72_Cond_0, Latency: [14407.061]
# Type: RingPassed_Cond_0, Latency: [14407.542]
# Type: ECG-RingPassed_Size_72, Latency: [14418.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [14418.]
# Type: ECG-RingPassed_Cond_0, Latency: [14418.]
# Type: QRS, Latency: [14418.]
# Type: QRS-C_OLoop, Latency: [14418.]
# Type: EBlnk-Off, Latency: [14422.]
# Type: EBlnk-Int-Off, Latency: [14550.]
# Type: StickMvmtPitch_All, Latency: [14566.682]
# Type: StickMvmtPitch_Size_72, Latency: [14567.198]
# Type: ECG-RingPassed_Size_72, Latency: [14615.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [14615.]
# Type: ECG-RingPassed_Cond_0, Latency: [14615.]
# Type: QRS, Latency: [14615.]
# Type: QRS-C_OLoop, Latency: [14615.]
# Type: EBlnk-Int-On, Latency: [14711.]
# Type: ECG-RingPassed_Size_72, Latency: [14817.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [14817.]
# Type: ECG-RingPassed_Cond_0, Latency: [14817.]
# Type: QRS, Latency: [14817.]
# Type: QRS-C_OLoop, Latency: [14817.]
# Type: EBlnk-On, Latency: [14839.]
# Type: EBlnk-Off, Latency: [14865.]
# Type: RingPassed_Size_72, Latency: [14921.515]
# Type: RingPassed_Size_72_Cond_0, Latency: [14922.043]
# Type: RingPassed_Cond_0, Latency: [14922.534]
# Type: StickMvmtPitch_All, Latency: [14989.851]
# Type: StickMvmtPitch_Size_72, Latency: [14990.376]
# Type: EBlnk-Int-Off, Latency: [14993.]
# Type: ECG-RingPassed_Size_72, Latency: [15010.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [15010.]
# Type: ECG-RingPassed_Cond_0, Latency: [15010.]
# Type: QRS, Latency: [15010.]
# Type: QRS-C_OLoop, Latency: [15010.]
# Type: ECG-RingPassed_Size_72, Latency: [15195.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [15195.]
# Type: ECG-RingPassed_Cond_0, Latency: [15195.]
# Type: QRS, Latency: [15195.]
# Type: QRS-C_OLoop, Latency: [15195.]
# Type: StickMvmtPitch_All, Latency: [15266.309]
# Type: StickMvmtPitch_Size_72, Latency: [15266.811]
# Type: ECG-RingPassed_Size_72, Latency: [15383.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [15383.]
# Type: ECG-RingPassed_Cond_0, Latency: [15383.]
# Type: QRS, Latency: [15383.]
# Type: QRS-C_OLoop, Latency: [15383.]
# Type: RingPassed_Size_72, Latency: [15433.492]
# Type: RingPassed_Size_72_Cond_0, Latency: [15434.001]
# Type: RingPassed_Cond_0, Latency: [15434.488]
# Type: ECG-RingPassed_Size_72, Latency: [15580.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [15580.]
# Type: ECG-RingPassed_Cond_0, Latency: [15580.]
# Type: QRS, Latency: [15580.]
# Type: QRS-C_OLoop, Latency: [15580.]
# Type: ECG-RingPassed_Size_72, Latency: [15779.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [15779.]
# Type: ECG-RingPassed_Cond_0, Latency: [15779.]
# Type: QRS, Latency: [15779.]
# Type: QRS-C_OLoop, Latency: [15779.]
# Type: RingPassed_Size_72, Latency: [15952.649]
# Type: RingPassed_Size_72_Cond_0, Latency: [15953.149]
# Type: RingPassed_Cond_0, Latency: [15953.631]
# Type: ECG-RingPassed_Size_72, Latency: [15982.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [15982.]
# Type: ECG-RingPassed_Cond_0, Latency: [15982.]
# Type: QRS, Latency: [15982.]
# Type: QRS-C_OLoop, Latency: [15982.]
# Type: StickMvmtPitch_All, Latency: [16095.682]
# Type: StickMvmtPitch_Size_36, Latency: [16096.204]
# Type: ECG-RingPassed_Size_72, Latency: [16193.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [16193.]
# Type: ECG-RingPassed_Cond_0, Latency: [16193.]
# Type: QRS, Latency: [16193.]
# Type: QRS-C_OLoop, Latency: [16193.]
# Type: ECG-RingPassed_Size_72, Latency: [16392.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [16392.]
# Type: ECG-RingPassed_Cond_0, Latency: [16392.]
# Type: QRS, Latency: [16392.]
# Type: QRS-C_OLoop, Latency: [16392.]
# Type: RingBound_Small, Latency: [16462.227]
# Type: RingPassed_Size_36, Latency: [16471.227]
# Type: RingPassed_Size_36_Cond_0, Latency: [16471.733]
# Type: RingPassed_Cond_0, Latency: [16472.219]
# Type: StickMvmtPitch_All, Latency: [16508.492]
# Type: StickMvmtPitch_Size_36, Latency: [16509.007]
# Type: ECG-RingPassed_Size_36, Latency: [16592.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [16592.]
# Type: ECG-RingPassed_Cond_0, Latency: [16592.]
# Type: QRS, Latency: [16592.]
# Type: QRS-C_OLoop, Latency: [16592.]
# Type: ECG-RingPassed_Size_36, Latency: [16795.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [16795.]
# Type: ECG-RingPassed_Cond_0, Latency: [16795.]
# Type: QRS, Latency: [16795.]
# Type: QRS-C_OLoop, Latency: [16795.]
# Type: EBlnk-Int-On, Latency: [16849.]
# Type: StickMvmtPitch_All, Latency: [16901.177]
# Type: StickMvmtPitch_Size_36, Latency: [16901.683]
# Type: EBlnk-On, Latency: [16977.]
# Type: RingPassed_Size_36, Latency: [16989.825]
# Type: ECG-RingPassed_Size_36, Latency: [16990.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [16990.]
# Type: ECG-RingPassed_Cond_0, Latency: [16990.]
# Type: QRS, Latency: [16990.]
# Type: QRS-C_OLoop, Latency: [16990.]
# Type: RingPassed_Size_36_Cond_0, Latency: [16990.341]
# Type: RingPassed_Cond_0, Latency: [16990.833]
# Type: EBlnk-Off, Latency: [16994.]
# Type: StickMvmtPitch_All, Latency: [17116.195]
# Type: StickMvmtPitch_Size_36, Latency: [17116.696]
# Type: EBlnk-Int-Off, Latency: [17122.]
# Type: ECG-RingPassed_Size_36, Latency: [17182.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [17182.]
# Type: ECG-RingPassed_Cond_0, Latency: [17182.]
# Type: QRS, Latency: [17182.]
# Type: QRS-C_OLoop, Latency: [17182.]
# Type: ECG-RingPassed_Size_36, Latency: [17375.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [17375.]
# Type: ECG-RingPassed_Cond_0, Latency: [17375.]
# Type: QRS, Latency: [17375.]
# Type: QRS-C_OLoop, Latency: [17375.]
# Type: StickMvmtPitch_All, Latency: [17389.11]
# Type: StickMvmtPitch_Size_36, Latency: [17389.623]
# Type: RingPassed_Size_36, Latency: [17505.209]
# Type: RingPassed_Size_36_Cond_0, Latency: [17505.73]
# Type: RingPassed_Cond_0, Latency: [17506.224]
# Type: ECG-RingPassed_Size_36, Latency: [17563.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [17563.]
# Type: ECG-RingPassed_Cond_0, Latency: [17563.]
# Type: QRS, Latency: [17563.]
# Type: QRS-C_OLoop, Latency: [17563.]
# Type: ECG-RingPassed_Size_36, Latency: [17746.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [17746.]
# Type: ECG-RingPassed_Cond_0, Latency: [17746.]
# Type: QRS, Latency: [17746.]
# Type: QRS-C_OLoop, Latency: [17746.]
# Type: StickMvmtPitch_All, Latency: [17822.711]
# Type: StickMvmtPitch_Size_36, Latency: [17823.219]
# Type: ECG-RingPassed_Size_36, Latency: [17937.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [17937.]
# Type: ECG-RingPassed_Cond_0, Latency: [17937.]
# Type: QRS, Latency: [17937.]
# Type: QRS-C_OLoop, Latency: [17937.]
# Type: RingPassed_Size_36, Latency: [18034.249]
# Type: RingPassed_Size_36_Cond_0, Latency: [18034.76]
# Type: RingPassed_Cond_0, Latency: [18035.25]
# Type: StickMvmtPitch_All, Latency: [18092.318]
# Type: StickMvmtPitch_Size_36, Latency: [18092.825]
# Type: QRS, Latency: [18132.]
# Type: QRS-C_OLoop, Latency: [18132.]
# Type: StickMvmtPitch_All, Latency: [18338.079]
# Type: StickMvmtPitch_Size_36, Latency: [18338.581]
# Type: boundary, Latency: [18553.5]
# Type: EBlnk-Int-On, Latency: [18554.]
# Type: EBlnk-On, Latency: [18554.]
# Type: EBlnk-Off, Latency: [18596.]
# Type: EBlnk-Int-Off, Latency: [18724.]
# Type: EBlnk-Int-On, Latency: [18834.]
# Type: QRS, Latency: [18962.]
# Type: QRS-C_OLoop, Latency: [18962.]
# Type: EBlnk-On, Latency: [18962.]
# Type: EBlnk-Off, Latency: [19022.]
# Type: EBlnk-Int-On, Latency: [19103.]
# Type: EBlnk-Int-Off, Latency: [19150.]
# Type: QRS, Latency: [19228.]
# Type: QRS-C_OLoop, Latency: [19228.]
# Type: EBlnk-On, Latency: [19231.]
# Type: EBlnk-Off, Latency: [19273.]
# Type: START-C_OLoop, Latency: [19323.929]
# Type: START-C_OLoop-LEN-64483, Latency: [19323.929]
# Type: START-C_OLoop-Crs-Easy-Cnd-0-LEN-64483, Latency: [19323.929]
# Type: EBlnk-Int-Off, Latency: [19401.]
# Type: QRS, Latency: [19477.]
# Type: QRS-C_OLoop, Latency: [19477.]
# Type: RingBound_Large, Latency: [19568.954]
# Type: Start_108_Cond_0, Latency: [19569.445]
# Type: StickMvmtPitch_All, Latency: [19576.369]
# Type: StickMvmtPitch_Size_108, Latency: [19576.967]
# Type: RingPassed_Size_108, Latency: [19577.954]
# Type: RingPassed_Size_108_Cond_0, Latency: [19578.445]
# Type: RingPassed_Cond_0, Latency: [19578.929]
# Type: ECG-RingPassed_Size_108, Latency: [19735.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [19735.]
# Type: ECG-RingPassed_Cond_0, Latency: [19735.]
# Type: QRS, Latency: [19735.]
# Type: QRS-C_OLoop, Latency: [19735.]
# Type: ECG-RingPassed_Size_108, Latency: [19990.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [19990.]
# Type: ECG-RingPassed_Cond_0, Latency: [19990.]
# Type: QRS, Latency: [19990.]
# Type: QRS-C_OLoop, Latency: [19990.]
# Type: StickMvmtPitch_All, Latency: [20027.102]
# Type: StickMvmtPitch_Size_108, Latency: [20027.61]
# Type: RingPassed_Size_108, Latency: [20088.334]
# Type: RingPassed_Size_108_Cond_0, Latency: [20088.84]
# Type: RingPassed_Cond_0, Latency: [20089.325]
# Type: ECG-RingPassed_Size_108, Latency: [20237.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [20237.]
# Type: ECG-RingPassed_Cond_0, Latency: [20237.]
# Type: QRS, Latency: [20237.]
# Type: QRS-C_OLoop, Latency: [20237.]
# Type: ECG-RingPassed_Size_108, Latency: [20502.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [20502.]
# Type: ECG-RingPassed_Cond_0, Latency: [20502.]
# Type: QRS, Latency: [20502.]
# Type: QRS-C_OLoop, Latency: [20502.]
# Type: RingPassed_Size_108, Latency: [20600.3]
# Type: RingPassed_Size_108_Cond_0, Latency: [20600.805]
# Type: RingPassed_Cond_0, Latency: [20601.296]
# Type: ECG-RingPassed_Size_108, Latency: [20773.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [20773.]
# Type: ECG-RingPassed_Cond_0, Latency: [20773.]
# Type: QRS, Latency: [20773.]
# Type: QRS-C_OLoop, Latency: [20773.]
# Type: EBlnk-Int-On, Latency: [20994.]
# Type: StickMvmtPitch_All, Latency: [21013.065]
# Type: StickMvmtPitch_Size_108, Latency: [21013.608]
# Type: ECG-RingPassed_Size_108, Latency: [21059.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [21059.]
# Type: ECG-RingPassed_Cond_0, Latency: [21059.]
# Type: QRS, Latency: [21059.]
# Type: QRS-C_OLoop, Latency: [21059.]
# Type: RingPassed_Size_108, Latency: [21112.25]
# Type: RingPassed_Size_108_Cond_0, Latency: [21112.754]
# Type: RingPassed_Cond_0, Latency: [21113.246]
# Type: EBlnk-On, Latency: [21122.]
# Type: EBlnk-Off, Latency: [21152.]
# Type: EBlnk-Int-Off, Latency: [21280.]
# Type: ECG-RingPassed_Size_108, Latency: [21338.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [21338.]
# Type: ECG-RingPassed_Cond_0, Latency: [21338.]
# Type: QRS, Latency: [21338.]
# Type: QRS-C_OLoop, Latency: [21338.]
# Type: ECG-RingPassed_Size_108, Latency: [21607.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [21607.]
# Type: ECG-RingPassed_Cond_0, Latency: [21607.]
# Type: QRS, Latency: [21607.]
# Type: QRS-C_OLoop, Latency: [21607.]
# Type: EBlnk-Int-On, Latency: [21612.]
# Type: RingPassed_Size_108, Latency: [21627.469]
# Type: RingPassed_Size_108_Cond_0, Latency: [21627.978]
# Type: RingPassed_Cond_0, Latency: [21628.471]
# Type: StickMvmtPitch_All, Latency: [21699.097]
# Type: StickMvmtPitch_Size_108, Latency: [21699.616]
# Type: EBlnk-On, Latency: [21740.]
# Type: EBlnk-Off, Latency: [21761.]
# Type: ECG-RingPassed_Size_108, Latency: [21873.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [21873.]
# Type: ECG-RingPassed_Cond_0, Latency: [21873.]
# Type: QRS, Latency: [21873.]
# Type: QRS-C_OLoop, Latency: [21873.]
# Type: EBlnk-Int-Off, Latency: [21889.]
# Type: ECG-RingPassed_Size_108, Latency: [22124.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [22124.]
# Type: ECG-RingPassed_Cond_0, Latency: [22124.]
# Type: QRS, Latency: [22124.]
# Type: QRS-C_OLoop, Latency: [22124.]
# Type: RingPassed_Size_108, Latency: [22139.469]
# Type: RingPassed_Size_108_Cond_0, Latency: [22140.003]
# Type: RingPassed_Cond_0, Latency: [22140.492]
# Type: ECG-RingPassed_Size_108, Latency: [22372.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [22372.]
# Type: ECG-RingPassed_Cond_0, Latency: [22372.]
# Type: QRS, Latency: [22372.]
# Type: QRS-C_OLoop, Latency: [22372.]
# Type: ECG-RingPassed_Size_108, Latency: [22651.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [22651.]
# Type: ECG-RingPassed_Cond_0, Latency: [22651.]
# Type: QRS, Latency: [22651.]
# Type: QRS-C_OLoop, Latency: [22651.]
# Type: RingPassed_Size_108, Latency: [22654.984]
# Type: RingPassed_Size_108_Cond_0, Latency: [22655.554]
# Type: RingPassed_Cond_0, Latency: [22656.052]
# Type: EBlnk-Int-On, Latency: [22677.]
# Type: StickMvmtPitch_All, Latency: [22763.977]
# Type: StickMvmtPitch_Size_108, Latency: [22764.489]
# Type: EBlnk-On, Latency: [22805.]
# Type: EBlnk-Off, Latency: [22835.]
# Type: ECG-RingPassed_Size_108, Latency: [22919.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [22919.]
# Type: ECG-RingPassed_Cond_0, Latency: [22919.]
# Type: QRS, Latency: [22919.]
# Type: QRS-C_OLoop, Latency: [22919.]
# Type: StickMvmtPitch_All, Latency: [22945.011]
# Type: StickMvmtPitch_Size_108, Latency: [22945.515]
# Type: EBlnk-Int-Off, Latency: [22963.]
# Type: RingPassed_Size_108, Latency: [23166.938]
# Type: RingPassed_Size_108_Cond_0, Latency: [23167.443]
# Type: RingPassed_Cond_0, Latency: [23168.022]
# Type: ECG-RingPassed_Size_108, Latency: [23198.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [23198.]
# Type: ECG-RingPassed_Cond_0, Latency: [23198.]
# Type: QRS, Latency: [23198.]
# Type: QRS-C_OLoop, Latency: [23198.]
# Type: StickMvmtPitch_All, Latency: [23279.566]
# Type: StickMvmtPitch_Size_108, Latency: [23280.134]
# Type: ECG-RingPassed_Size_108, Latency: [23485.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [23485.]
# Type: ECG-RingPassed_Cond_0, Latency: [23485.]
# Type: QRS, Latency: [23485.]
# Type: QRS-C_OLoop, Latency: [23485.]
# Type: StickMvmtPitch_All, Latency: [23491.085]
# Type: StickMvmtPitch_Size_108, Latency: [23491.592]
# Type: RingPassed_Size_108, Latency: [23682.157]
# Type: RingPassed_Size_108_Cond_0, Latency: [23682.667]
# Type: RingPassed_Cond_0, Latency: [23683.159]
# Type: StickMvmtPitch_All, Latency: [23695.894]
# Type: StickMvmtPitch_Size_108, Latency: [23696.4]
# Type: ECG-RingPassed_Size_108, Latency: [23764.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [23764.]
# Type: ECG-RingPassed_Cond_0, Latency: [23764.]
# Type: QRS, Latency: [23764.]
# Type: QRS-C_OLoop, Latency: [23764.]
# Type: ECG-RingPassed_Size_108, Latency: [24048.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [24048.]
# Type: ECG-RingPassed_Cond_0, Latency: [24048.]
# Type: QRS, Latency: [24048.]
# Type: QRS-C_OLoop, Latency: [24048.]
# Type: RingPassed_Size_108, Latency: [24194.123]
# Type: RingPassed_Size_108_Cond_0, Latency: [24194.64]
# Type: RingPassed_Cond_0, Latency: [24195.128]
# Type: ECG-RingPassed_Size_108, Latency: [24315.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [24315.]
# Type: ECG-RingPassed_Cond_0, Latency: [24315.]
# Type: QRS, Latency: [24315.]
# Type: QRS-C_OLoop, Latency: [24315.]
# Type: StickMvmtPitch_All, Latency: [24484.174]
# Type: StickMvmtPitch_Size_108, Latency: [24484.694]
# Type: EBlnk-Int-On, Latency: [24535.]
# Type: ECG-RingPassed_Size_108, Latency: [24584.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [24584.]
# Type: ECG-RingPassed_Cond_0, Latency: [24584.]
# Type: QRS, Latency: [24584.]
# Type: QRS-C_OLoop, Latency: [24584.]
# Type: EBlnk-On, Latency: [24663.]
# Type: EBlnk-Off, Latency: [24705.]
# Type: RingPassed_Size_108, Latency: [24713.092]
# Type: RingPassed_Size_108_Cond_0, Latency: [24713.596]
# Type: RingPassed_Cond_0, Latency: [24714.082]
# Type: EBlnk-Int-Off, Latency: [24833.]
# Type: ECG-RingPassed_Size_108, Latency: [24851.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [24851.]
# Type: ECG-RingPassed_Cond_0, Latency: [24851.]
# Type: QRS, Latency: [24851.]
# Type: QRS-C_OLoop, Latency: [24851.]
# Type: ECG-RingPassed_Size_108, Latency: [25089.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [25089.]
# Type: ECG-RingPassed_Cond_0, Latency: [25089.]
# Type: QRS, Latency: [25089.]
# Type: QRS-C_OLoop, Latency: [25089.]
# Type: RingPassed_Size_108, Latency: [25228.32]
# Type: RingPassed_Size_108_Cond_0, Latency: [25228.836]
# Type: RingPassed_Cond_0, Latency: [25229.33]
# Type: ECG-RingPassed_Size_108, Latency: [25341.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [25341.]
# Type: ECG-RingPassed_Cond_0, Latency: [25341.]
# Type: QRS, Latency: [25341.]
# Type: QRS-C_OLoop, Latency: [25341.]
# Type: ECG-RingPassed_Size_108, Latency: [25598.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [25598.]
# Type: ECG-RingPassed_Cond_0, Latency: [25598.]
# Type: QRS, Latency: [25598.]
# Type: QRS-C_OLoop, Latency: [25598.]
# Type: StickMvmtPitch_All, Latency: [25655.014]
# Type: StickMvmtPitch_Size_108, Latency: [25655.583]
# Type: RingPassed_Size_108, Latency: [25743.802]
# Type: RingPassed_Size_108_Cond_0, Latency: [25744.318]
# Type: RingPassed_Cond_0, Latency: [25746.246]
# Type: ECG-RingPassed_Size_108, Latency: [25842.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [25842.]
# Type: ECG-RingPassed_Cond_0, Latency: [25842.]
# Type: QRS, Latency: [25842.]
# Type: QRS-C_OLoop, Latency: [25842.]
# Type: ECG-RingPassed_Size_108, Latency: [26110.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [26110.]
# Type: ECG-RingPassed_Cond_0, Latency: [26110.]
# Type: QRS, Latency: [26110.]
# Type: QRS-C_OLoop, Latency: [26110.]
# Type: RingPassed_Size_108, Latency: [26255.883]
# Type: RingPassed_Size_108_Cond_0, Latency: [26256.443]
# Type: RingPassed_Cond_0, Latency: [26256.946]
# Type: ECG-RingPassed_Size_108, Latency: [26364.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [26364.]
# Type: ECG-RingPassed_Cond_0, Latency: [26364.]
# Type: QRS, Latency: [26364.]
# Type: QRS-C_OLoop, Latency: [26364.]
# Type: StickMvmtPitch_All, Latency: [26579.861]
# Type: StickMvmtPitch_Size_108, Latency: [26580.452]
# Type: ECG-RingPassed_Size_108, Latency: [26607.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [26607.]
# Type: ECG-RingPassed_Cond_0, Latency: [26607.]
# Type: QRS, Latency: [26607.]
# Type: QRS-C_OLoop, Latency: [26607.]
# Type: RingPassed_Size_108, Latency: [26767.757]
# Type: RingPassed_Size_108_Cond_0, Latency: [26768.26]
# Type: RingPassed_Cond_0, Latency: [26770.191]
# Type: ECG-RingPassed_Size_108, Latency: [26855.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [26855.]
# Type: ECG-RingPassed_Cond_0, Latency: [26855.]
# Type: QRS, Latency: [26855.]
# Type: QRS-C_OLoop, Latency: [26855.]
# Type: StickMvmtPitch_All, Latency: [26999.859]
# Type: StickMvmtPitch_Size_72, Latency: [27000.369]
# Type: ECG-RingPassed_Size_108, Latency: [27099.]
# Type: ECG-RingPassed_Size_108_Cond_0, Latency: [27099.]
# Type: ECG-RingPassed_Cond_0, Latency: [27099.]
# Type: QRS, Latency: [27099.]
# Type: QRS-C_OLoop, Latency: [27099.]
# Type: EBlnk-Int-On, Latency: [27180.]
# Type: StickMvmtPitch_All, Latency: [27214.648]
# Type: StickMvmtPitch_Size_72, Latency: [27215.158]
# Type: RingBound_Medium, Latency: [27277.407]
# Type: RingPassed_Size_72, Latency: [27286.407]
# Type: RingPassed_Size_72_Cond_0, Latency: [27286.924]
# Type: RingPassed_Cond_0, Latency: [27287.419]
# Type: EBlnk-On, Latency: [27308.]
# Type: EBlnk-Off, Latency: [27317.]
# Type: ECG-RingPassed_Size_72, Latency: [27346.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [27346.]
# Type: ECG-RingPassed_Cond_0, Latency: [27346.]
# Type: QRS, Latency: [27346.]
# Type: QRS-C_OLoop, Latency: [27346.]
# Type: EBlnk-Int-Off, Latency: [27445.]
# Type: ECG-RingPassed_Size_72, Latency: [27597.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [27597.]
# Type: ECG-RingPassed_Cond_0, Latency: [27597.]
# Type: QRS, Latency: [27597.]
# Type: QRS-C_OLoop, Latency: [27597.]
# Type: RingPassed_Size_72, Latency: [27801.916]
# Type: RingPassed_Size_72_Cond_0, Latency: [27802.422]
# Type: RingPassed_Cond_0, Latency: [27802.909]
# Type: ECG-RingPassed_Size_72, Latency: [27840.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [27840.]
# Type: ECG-RingPassed_Cond_0, Latency: [27840.]
# Type: QRS, Latency: [27840.]
# Type: QRS-C_OLoop, Latency: [27840.]
# Type: ECG-RingPassed_Size_72, Latency: [28089.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [28089.]
# Type: ECG-RingPassed_Cond_0, Latency: [28089.]
# Type: QRS, Latency: [28089.]
# Type: QRS-C_OLoop, Latency: [28089.]
# Type: StickMvmtPitch_All, Latency: [28194.337]
# Type: StickMvmtPitch_Size_72, Latency: [28194.84]
# Type: RingPassed_Size_72, Latency: [28320.611]
# Type: RingPassed_Size_72_Cond_0, Latency: [28321.141]
# Type: RingPassed_Cond_0, Latency: [28321.63]
# Type: ECG-RingPassed_Size_72, Latency: [28337.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [28337.]
# Type: ECG-RingPassed_Cond_0, Latency: [28337.]
# Type: QRS, Latency: [28337.]
# Type: QRS-C_OLoop, Latency: [28337.]
# Type: ECG-RingPassed_Size_72, Latency: [28576.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [28576.]
# Type: ECG-RingPassed_Cond_0, Latency: [28576.]
# Type: QRS, Latency: [28576.]
# Type: QRS-C_OLoop, Latency: [28576.]
# Type: StickMvmtPitch_All, Latency: [28685.851]
# Type: StickMvmtPitch_Size_72, Latency: [28686.363]
# Type: ECG-RingPassed_Size_72, Latency: [28817.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [28817.]
# Type: ECG-RingPassed_Cond_0, Latency: [28817.]
# Type: QRS, Latency: [28817.]
# Type: QRS-C_OLoop, Latency: [28817.]
# Type: RingPassed_Size_72, Latency: [28832.557]
# Type: RingPassed_Size_72_Cond_0, Latency: [28833.07]
# Type: RingPassed_Cond_0, Latency: [28833.566]
# Type: StickMvmtPitch_All, Latency: [29040.81]
# Type: StickMvmtPitch_Size_72, Latency: [29041.325]
# Type: ECG-RingPassed_Size_72, Latency: [29048.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [29048.]
# Type: ECG-RingPassed_Cond_0, Latency: [29048.]
# Type: QRS, Latency: [29048.]
# Type: QRS-C_OLoop, Latency: [29048.]
# Type: ECG-RingPassed_Size_72, Latency: [29272.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [29272.]
# Type: ECG-RingPassed_Cond_0, Latency: [29272.]
# Type: QRS, Latency: [29272.]
# Type: QRS-C_OLoop, Latency: [29272.]
# Type: RingPassed_Size_72, Latency: [29354.741]
# Type: RingPassed_Size_72_Cond_0, Latency: [29355.258]
# Type: RingPassed_Cond_0, Latency: [29355.743]
# Type: StickMvmtPitch_All, Latency: [29460.599]
# Type: StickMvmtPitch_Size_72, Latency: [29461.154]
# Type: ECG-RingPassed_Size_72, Latency: [29510.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [29510.]
# Type: ECG-RingPassed_Cond_0, Latency: [29510.]
# Type: QRS, Latency: [29510.]
# ...
# Type: QRS-C_OLoop, Latency: [131271.]
# Type: RingPassed_Size_72, Latency: [131279.436]
# Type: RingPassed_Size_72_Cond_0, Latency: [131279.942]
# Type: RingPassed_Cond_0, Latency: [131280.426]
# Type: EBlnk-Int-Off, Latency: [131324.]
# Type: saccade, Latency: [131351.]
# Type: fixation, Latency: [131376.]
# Type: saccade, Latency: [131452.]
# Type: fixation, Latency: [131461.]
# Type: StickMvmtPitch_All, Latency: [131477.331]
# Type: StickMvmtPitch_Size_72, Latency: [131479.237]
# Type: ECG-RingPassed_Size_72, Latency: [131495.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [131495.]
# Type: ECG-RingPassed_Cond_0, Latency: [131495.]
# Type: QRS, Latency: [131495.]
# Type: QRS-C_OLoop, Latency: [131495.]
# Type: saccade, Latency: [131661.]
# Type: fixation, Latency: [131675.]
# Type: ECG-RingPassed_Size_72, Latency: [131717.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [131717.]
# Type: ECG-RingPassed_Cond_0, Latency: [131717.]
# Type: QRS, Latency: [131717.]
# Type: QRS-C_OLoop, Latency: [131717.]
# Type: saccade, Latency: [131721.]
# Type: EBlnk-Int-On, Latency: [131725.]
# Type: fixation, Latency: [131725.]
# Type: RingPassed_Size_72, Latency: [131798.075]
# Type: RingPassed_Size_72_Cond_0, Latency: [131798.597]
# Type: RingPassed_Cond_0, Latency: [131799.092]
# Type: EBlnk-On, Latency: [131853.]
# Type: EBlnk-Off, Latency: [131866.]
# Type: StickMvmtPitch_All, Latency: [131920.856]
# Type: StickMvmtPitch_Size_72, Latency: [131921.423]
# Type: ECG-RingPassed_Size_72, Latency: [131936.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [131936.]
# Type: ECG-RingPassed_Cond_0, Latency: [131936.]
# Type: QRS, Latency: [131936.]
# Type: QRS-C_OLoop, Latency: [131936.]
# Type: EBlnk-Int-Off, Latency: [131994.]
# Type: ECG-RingPassed_Size_72, Latency: [132170.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [132170.]
# Type: ECG-RingPassed_Cond_0, Latency: [132170.]
# Type: QRS, Latency: [132170.]
# Type: QRS-C_OLoop, Latency: [132170.]
# Type: saccade, Latency: [132212.]
# Type: fixation, Latency: [132216.]
# Type: saccade, Latency: [132288.]
# Type: RingPassed_Size_72, Latency: [132313.6]
# Type: fixation, Latency: [132314.]
# Type: RingPassed_Size_72_Cond_0, Latency: [132314.181]
# Type: RingPassed_Cond_0, Latency: [132314.704]
# Type: ECG-RingPassed_Size_72, Latency: [132413.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [132413.]
# Type: ECG-RingPassed_Cond_0, Latency: [132413.]
# Type: QRS, Latency: [132413.]
# Type: QRS-C_OLoop, Latency: [132413.]
# Type: StickMvmtPitch_All, Latency: [132610.465]
# Type: StickMvmtPitch_Size_72, Latency: [132610.971]
# Type: saccade, Latency: [132630.]
# Type: ECG-RingPassed_Size_72, Latency: [132645.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [132645.]
# Type: ECG-RingPassed_Cond_0, Latency: [132645.]
# Type: QRS, Latency: [132645.]
# Type: QRS-C_OLoop, Latency: [132645.]
# Type: fixation, Latency: [132651.]
# Type: RingPassed_Size_72, Latency: [132825.542]
# Type: RingPassed_Size_72_Cond_0, Latency: [132826.048]
# Type: RingPassed_Cond_0, Latency: [132826.529]
# Type: ECG-RingPassed_Size_72, Latency: [132876.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [132876.]
# Type: ECG-RingPassed_Cond_0, Latency: [132876.]
# Type: QRS, Latency: [132876.]
# Type: QRS-C_OLoop, Latency: [132876.]
# Type: saccade, Latency: [133009.]
# Type: fixation, Latency: [133013.]
# Type: StickMvmtPitch_All, Latency: [133067.639]
# Type: StickMvmtPitch_Size_72, Latency: [133068.215]
# Type: ECG-RingPassed_Size_72, Latency: [133107.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [133107.]
# Type: ECG-RingPassed_Cond_0, Latency: [133107.]
# Type: QRS, Latency: [133107.]
# Type: QRS-C_OLoop, Latency: [133107.]
# Type: saccade, Latency: [133192.]
# Type: fixation, Latency: [133209.]
# Type: StickMvmtPitch_All, Latency: [133282.687]
# Type: StickMvmtPitch_Size_72, Latency: [133283.204]
# Type: saccade, Latency: [133316.]
# Type: ECG-RingPassed_Size_72, Latency: [133324.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [133324.]
# Type: ECG-RingPassed_Cond_0, Latency: [133324.]
# Type: QRS, Latency: [133324.]
# Type: QRS-C_OLoop, Latency: [133324.]
# Type: fixation, Latency: [133333.]
# Type: RingPassed_Size_72, Latency: [133344.17]
# Type: RingPassed_Size_72_Cond_0, Latency: [133344.677]
# Type: RingPassed_Cond_0, Latency: [133345.17]
# Type: saccade, Latency: [133452.]
# Type: StickMvmtPitch_All, Latency: [133456.751]
# Type: StickMvmtPitch_Size_36, Latency: [133457.27]
# Type: fixation, Latency: [133461.]
# Type: saccade, Latency: [133503.]
# Type: fixation, Latency: [133517.]
# Type: ECG-RingPassed_Size_72, Latency: [133545.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [133545.]
# Type: ECG-RingPassed_Cond_0, Latency: [133545.]
# Type: QRS, Latency: [133545.]
# Type: QRS-C_OLoop, Latency: [133545.]
# Type: saccade, Latency: [133559.]
# Type: fixation, Latency: [133567.]
# Type: saccade, Latency: [133746.]
# Type: ECG-RingPassed_Size_72, Latency: [133763.]
# Type: ECG-RingPassed_Size_72_Cond_0, Latency: [133763.]
# Type: ECG-RingPassed_Cond_0, Latency: [133763.]
# Type: QRS, Latency: [133763.]
# Type: QRS-C_OLoop, Latency: [133763.]
# Type: fixation, Latency: [133764.]
# Type: saccade, Latency: [133823.]
# Type: RingBound_Small, Latency: [133850.731]
# Type: fixation, Latency: [133858.]
# Type: RingPassed_Size_36, Latency: [133859.731]
# Type: RingPassed_Size_36_Cond_0, Latency: [133860.247]
# Type: RingPassed_Cond_0, Latency: [133860.742]
# Type: saccade, Latency: [133896.]
# Type: fixation, Latency: [133905.]
# Type: ECG-RingPassed_Size_36, Latency: [133976.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [133976.]
# Type: ECG-RingPassed_Cond_0, Latency: [133976.]
# Type: QRS, Latency: [133976.]
# Type: QRS-C_OLoop, Latency: [133976.]
# Type: StickMvmtPitch_All, Latency: [134067.829]
# Type: StickMvmtPitch_Size_36, Latency: [134068.331]
# Type: EBlnk-Int-On, Latency: [134142.]
# Type: ECG-RingPassed_Size_36, Latency: [134200.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [134200.]
# Type: ECG-RingPassed_Cond_0, Latency: [134200.]
# Type: QRS, Latency: [134200.]
# Type: QRS-C_OLoop, Latency: [134200.]
# Type: EBlnk-On, Latency: [134270.]
# Type: EBlnk-Off, Latency: [134279.]
# Type: RingPassed_Size_36, Latency: [134375.926]
# Type: RingPassed_Size_36_Cond_0, Latency: [134376.737]
# Type: RingPassed_Cond_0, Latency: [134377.422]
# Type: StickMvmtPitch_All, Latency: [134398.777]
# Type: StickMvmtPitch_Size_36, Latency: [134399.448]
# Type: EBlnk-Int-Off, Latency: [134407.]
# Type: ECG-RingPassed_Size_36, Latency: [134421.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [134421.]
# Type: ECG-RingPassed_Cond_0, Latency: [134421.]
# Type: QRS, Latency: [134421.]
# Type: QRS-C_OLoop, Latency: [134421.]
# Type: saccade, Latency: [134428.]
# Type: fixation, Latency: [134442.]
# Type: ECG-RingPassed_Size_36, Latency: [134626.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [134626.]
# Type: ECG-RingPassed_Cond_0, Latency: [134626.]
# Type: QRS, Latency: [134626.]
# Type: QRS-C_OLoop, Latency: [134626.]
# Type: saccade, Latency: [134710.]
# Type: fixation, Latency: [134727.]
# Type: ECG-RingPassed_Size_36, Latency: [134846.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [134846.]
# Type: ECG-RingPassed_Cond_0, Latency: [134846.]
# Type: QRS, Latency: [134846.]
# Type: QRS-C_OLoop, Latency: [134846.]
# Type: RingPassed_Size_36, Latency: [134887.057]
# Type: RingPassed_Size_36_Cond_0, Latency: [134887.561]
# Type: RingPassed_Cond_0, Latency: [134888.056]
# Type: ECG-RingPassed_Size_36, Latency: [135073.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [135073.]
# Type: ECG-RingPassed_Cond_0, Latency: [135073.]
# Type: QRS, Latency: [135073.]
# Type: QRS-C_OLoop, Latency: [135073.]
# Type: saccade, Latency: [135124.]
# Type: fixation, Latency: [135132.]
# Type: ECG-RingPassed_Size_36, Latency: [135295.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [135295.]
# Type: ECG-RingPassed_Cond_0, Latency: [135295.]
# Type: QRS, Latency: [135295.]
# Type: QRS-C_OLoop, Latency: [135295.]
# Type: saccade, Latency: [135333.]
# Type: fixation, Latency: [135345.]
# Type: StickMvmtPitch_All, Latency: [135381.948]
# Type: StickMvmtPitch_Size_36, Latency: [135382.448]
# Type: RingPassed_Size_36, Latency: [135402.313]
# Type: RingPassed_Size_36_Cond_0, Latency: [135402.827]
# Type: RingPassed_Cond_0, Latency: [135403.326]
# Type: ECG-RingPassed_Size_36, Latency: [135519.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [135519.]
# Type: ECG-RingPassed_Cond_0, Latency: [135519.]
# Type: QRS, Latency: [135519.]
# Type: QRS-C_OLoop, Latency: [135519.]
# Type: saccade, Latency: [135528.]
# Type: fixation, Latency: [135542.]
# Type: saccade, Latency: [135678.]
# Type: fixation, Latency: [135708.]
# Type: ECG-RingPassed_Size_36, Latency: [135739.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [135739.]
# Type: ECG-RingPassed_Cond_0, Latency: [135739.]
# Type: QRS, Latency: [135739.]
# Type: QRS-C_OLoop, Latency: [135739.]
# Type: saccade, Latency: [135840.]
# Type: fixation, Latency: [135849.]
# Type: StickMvmtPitch_All, Latency: [135887.026]
# Type: StickMvmtPitch_Size_36, Latency: [135887.534]
# Type: RingPassed_Size_36, Latency: [135918.134]
# Type: RingPassed_Size_36_Cond_0, Latency: [135918.644]
# Type: RingPassed_Cond_0, Latency: [135919.131]
# Type: ECG-RingPassed_Size_36, Latency: [135947.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [135947.]
# Type: ECG-RingPassed_Cond_0, Latency: [135947.]
# Type: QRS, Latency: [135947.]
# Type: QRS-C_OLoop, Latency: [135947.]
# Type: saccade, Latency: [135959.]
# Type: fixation, Latency: [135972.]
# Type: ECG-RingPassed_Size_36, Latency: [136157.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [136157.]
# Type: ECG-RingPassed_Cond_0, Latency: [136157.]
# Type: QRS, Latency: [136157.]
# Type: QRS-C_OLoop, Latency: [136157.]
# Type: StickMvmtPitch_All, Latency: [136214.768]
# Type: StickMvmtPitch_Size_36, Latency: [136215.358]
# Type: saccade, Latency: [136249.]
# Type: fixation, Latency: [136267.]
# Type: StickMvmtPitch_All, Latency: [136341.228]
# Type: StickMvmtPitch_Size_36, Latency: [136341.723]
# Type: ECG-RingPassed_Size_36, Latency: [136357.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [136357.]
# Type: ECG-RingPassed_Cond_0, Latency: [136357.]
# Type: QRS, Latency: [136357.]
# Type: QRS-C_OLoop, Latency: [136357.]
# Type: RingPassed_Size_36, Latency: [136429.754]
# Type: RingPassed_Size_36_Cond_0, Latency: [136430.246]
# Type: RingPassed_Cond_0, Latency: [136430.727]
# Type: EBlnk-Int-On, Latency: [136483.]
# Type: ECG-RingPassed_Size_36, Latency: [136552.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [136552.]
# Type: ECG-RingPassed_Cond_0, Latency: [136552.]
# Type: QRS, Latency: [136552.]
# Type: QRS-C_OLoop, Latency: [136552.]
# Type: EBlnk-On, Latency: [136611.]
# Type: EBlnk-Off, Latency: [136633.]
# Type: StickMvmtPitch_All, Latency: [136644.719]
# Type: StickMvmtPitch_Size_36, Latency: [136645.232]
# Type: ECG-RingPassed_Size_36, Latency: [136750.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [136750.]
# Type: ECG-RingPassed_Cond_0, Latency: [136750.]
# Type: QRS, Latency: [136750.]
# Type: QRS-C_OLoop, Latency: [136750.]
# Type: EBlnk-Int-Off, Latency: [136761.]
# Type: saccade, Latency: [136876.]
# Type: fixation, Latency: [136885.]
# Type: ECG-RingPassed_Size_36, Latency: [136941.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [136941.]
# Type: ECG-RingPassed_Cond_0, Latency: [136941.]
# Type: QRS, Latency: [136941.]
# Type: QRS-C_OLoop, Latency: [136941.]
# Type: RingPassed_Size_36, Latency: [136941.768]
# Type: RingPassed_Size_36_Cond_0, Latency: [136942.28]
# Type: RingPassed_Cond_0, Latency: [136942.765]
# Type: saccade, Latency: [136945.]
# Type: fixation, Latency: [136961.]
# Type: saccade, Latency: [136996.]
# Type: StickMvmtPitch_All, Latency: [137030.281]
# Type: StickMvmtPitch_Size_36, Latency: [137030.838]
# Type: fixation, Latency: [137042.]
# Type: ECG-RingPassed_Size_36, Latency: [137139.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [137139.]
# Type: ECG-RingPassed_Cond_0, Latency: [137139.]
# Type: QRS, Latency: [137139.]
# Type: QRS-C_OLoop, Latency: [137139.]
# Type: saccade, Latency: [137140.]
# Type: fixation, Latency: [137183.]
# Type: StickMvmtPitch_All, Latency: [137204.385]
# Type: StickMvmtPitch_Size_36, Latency: [137204.951]
# Type: saccade, Latency: [137307.]
# Type: fixation, Latency: [137315.]
# Type: ECG-RingPassed_Size_36, Latency: [137340.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [137340.]
# Type: ECG-RingPassed_Cond_0, Latency: [137340.]
# Type: QRS, Latency: [137340.]
# Type: QRS-C_OLoop, Latency: [137340.]
# Type: RingPassed_Size_36, Latency: [137457.156]
# Type: RingPassed_Size_36_Cond_0, Latency: [137457.661]
# Type: RingPassed_Cond_0, Latency: [137458.153]
# Type: ECG-RingPassed_Size_36, Latency: [137538.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [137538.]
# Type: ECG-RingPassed_Cond_0, Latency: [137538.]
# Type: QRS, Latency: [137538.]
# Type: QRS-C_OLoop, Latency: [137538.]
# Type: saccade, Latency: [137618.]
# Type: fixation, Latency: [137635.]
# Type: StickMvmtPitch_All, Latency: [137689.253]
# Type: StickMvmtPitch_Size_36, Latency: [137689.81]
# Type: saccade, Latency: [137733.]
# Type: ECG-RingPassed_Size_36, Latency: [137745.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [137745.]
# Type: ECG-RingPassed_Cond_0, Latency: [137745.]
# Type: QRS, Latency: [137745.]
# Type: QRS-C_OLoop, Latency: [137745.]
# Type: fixation, Latency: [137784.]
# Type: ECG-RingPassed_Size_36, Latency: [137954.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [137954.]
# Type: ECG-RingPassed_Cond_0, Latency: [137954.]
# Type: QRS, Latency: [137954.]
# Type: QRS-C_OLoop, Latency: [137954.]
# Type: StickMvmtPitch_All, Latency: [137969.041]
# Type: StickMvmtPitch_Size_36, Latency: [137969.549]
# Type: RingPassed_Size_36, Latency: [137979.319]
# Type: RingPassed_Size_36_Cond_0, Latency: [137979.822]
# Type: RingPassed_Cond_0, Latency: [137980.31]
# Type: saccade, Latency: [138138.]
# Type: ECG-RingPassed_Size_36, Latency: [138150.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [138150.]
# Type: ECG-RingPassed_Cond_0, Latency: [138150.]
# Type: QRS, Latency: [138150.]
# Type: QRS-C_OLoop, Latency: [138150.]
# Type: fixation, Latency: [138151.]
# Type: StickMvmtPitch_All, Latency: [138184.029]
# Type: StickMvmtPitch_Size_36, Latency: [138184.518]
# Type: ECG-RingPassed_Size_36, Latency: [138347.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [138347.]
# Type: ECG-RingPassed_Cond_0, Latency: [138347.]
# Type: QRS, Latency: [138347.]
# Type: QRS-C_OLoop, Latency: [138347.]
# Type: saccade, Latency: [138432.]
# Type: fixation, Latency: [138445.]
# Type: saccade, Latency: [138471.]
# Type: RingPassed_Size_36, Latency: [138498.134]
# Type: RingPassed_Size_36_Cond_0, Latency: [138498.652]
# Type: RingPassed_Cond_0, Latency: [138499.142]
# Type: ECG-RingPassed_Size_36, Latency: [138541.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [138541.]
# Type: ECG-RingPassed_Cond_0, Latency: [138541.]
# Type: QRS, Latency: [138541.]
# Type: QRS-C_OLoop, Latency: [138541.]
# Type: StickMvmtPitch_All, Latency: [138583.35]
# Type: StickMvmtPitch_Size_36, Latency: [138583.865]
# Type: fixation, Latency: [138607.]
# Type: saccade, Latency: [138632.]
# Type: fixation, Latency: [138650.]
# Type: ECG-RingPassed_Size_36, Latency: [138728.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [138728.]
# Type: ECG-RingPassed_Cond_0, Latency: [138728.]
# Type: QRS, Latency: [138728.]
# Type: QRS-C_OLoop, Latency: [138728.]
# Type: saccade, Latency: [138765.]
# Type: fixation, Latency: [138778.]
# Type: saccade, Latency: [138851.]
# Type: StickMvmtPitch_All, Latency: [138873.446]
# Type: StickMvmtPitch_Size_36, Latency: [138873.968]
# Type: fixation, Latency: [138888.]
# Type: ECG-RingPassed_Size_36, Latency: [138915.]
# Type: ECG-RingPassed_Size_36_Cond_0, Latency: [138915.]
# Type: ECG-RingPassed_Cond_0, Latency: [138915.]
# Type: QRS, Latency: [138915.]
# Type: QRS-C_OLoop, Latency: [138915.]
# Type: saccade, Latency: [138962.]
# Type: fixation, Latency: [138974.]
# Type: RingPassed_Size_36, Latency: [139013.461]
# Type: RingPassed_Size_36_Cond_0, Latency: [139013.978]
# Type: RingPassed_Cond_0, Latency: [139014.473]
# Type: saccade, Latency: [139034.]
# Type: fixation, Latency: [139043.]
# Type: saccade, Latency: [139072.]
# Type: QRS, Latency: [139102.]
# Type: QRS-C_OLoop, Latency: [139102.]
# Type: StickMvmtPitch_All, Latency: [139139.566]
# Type: StickMvmtPitch_Size_36, Latency: [139140.08]
# Type: fixation, Latency: [139196.]
# Type: saccade, Latency: [139400.]
# Type: fixation, Latency: [139430.]

# %% [markdown]
# ## 2. Preprocessing and Analyzing EEG Data: Filtering, Epoch Extraction, and Artifact Removal
#
# We now perform preprocessing on the data below. The pipeline consists of the following steps:
# 1. **Filter data**:
#    - A Butterworth filter is implemented to perform band-pass filtering, allowing only frequencies within a specific range to pass (1-40 Hz). This step helps remove noise and focus on relevant brain activity signals.
#    - A high-pass filter is also applied when needed to meet the requirements for Independent Component Analysis (ICA).
# 2. **Reshape and preprocess data**:
#    - Raw EEG data is loaded from `.mat` files using `h5py` and reshaped to ensure consistency in format `(channels x time points)`.
#    - Preprocessing steps like NaN and infinite value handling are performed to prepare the data for further analysis.
# 3. **Extract epochs**:
#    - The EEG data is segmented into epochs around specific event markers, defined by experimental conditions. Each epoch represents brain activity surrounding a particular event, allowing for more targeted analysis.
# 4. **Remove artifacts with ICA**:
#    - Independent Component Analysis (ICA) is used to identify and remove artifacts, such as eye movements or muscle activity, from the EEG signals.
#    - High-pass filtered epochs are fed into the ICA model to ensure accurate component separation.
# 5. **Time-Frequency Analysis**:
#    - A time-frequency representation of the EEG data is computed using Morlet wavelet transforms. This provides insights into the power of different frequency bands over time, helping to capture dynamic changes in brain activity.
# 6. **Batch Processing and Memory Optimization**:
#    - To handle large datasets efficiently, EEG data is processed in smaller batches. This reduces memory usage and prevents kernel crashes.
#    - Garbage collection is used to free up memory after processing each batch.

# %%
# IMPORTANT: Switch `rerun` to `False` if you want to load the data (setting `rerun` to `True` runs the cell for a LONG TIME!!)
rerun = False

# %%
import os
import numpy as np
import h5py
from scipy.signal import butter, filtfilt
from mne.preprocessing import ICA
from mne import create_info, EpochsArray
from mne.time_frequency import tfr_morlet
from joblib import Parallel, delayed
import gc
import time

# Define Butterworth band-pass filter
def bandpass_filter(data, lowcut, highcut, fs, order=5):
    nyquist = 0.5 * fs
    if highcut is None:
        low = lowcut / nyquist
        b, a = butter(order, low, btype='high')
    else:
        low = lowcut / nyquist
        high = highcut / nyquist
        b, a = butter(order, [low, high], btype='band')
    return filtfilt(b, a, data, axis=1)

# Load and preprocess EEG data
def load_and_preprocess_eeg(file_path, lowcut=1.0, highcut=40, fs=250, max_retries=5, retry_delay=10):
    retries = 0
    while retries < max_retries:
        try:
            with h5py.File(file_path, 'r') as f:
                eeg_data = np.array(f['actualVariable']['EEG_full']['data'])
                if eeg_data.shape[1] == 144:
                    eeg_data = eeg_data.T

                filtered_data = bandpass_filter(eeg_data, lowcut, highcut, fs)
                filtered_data = np.nan_to_num(filtered_data)
                print(f"Preprocessed EEG Data Shape: {filtered_data.shape}")
                
                # Extract events
                events = f['actualVariable']['EEG_full']['event']
                event_labels = []
                for i in range(len(events['type'])):
                    event_type_ref = events['type'][i][0]
                    event_latency_ref = events['latency'][i][0]
                    event_type = ''.join(chr(x) for x in f[event_type_ref][:].flatten())
                    event_latency = f[event_latency_ref][()][0]
                    event_labels.append((event_type, event_latency))
                
                return filtered_data, event_labels
        except TimeoutError as e:
            retries += 1
            print(f"TimeoutError: {e}. Retrying ({retries}/{max_retries})...")
            time.sleep(retry_delay)
    raise TimeoutError(f"Failed to load file {file_path} after {max_retries} attempts.")

# Extract epochs around events
def epoch_eeg_data(eeg_data, event_labels, batch_start, batch_end, epoch_start=-0.2, epoch_end=0.8, fs=250):
    epochs = []
    labels = []
    for etype, elatency in event_labels:
        elatency_relative = elatency - batch_start
        start = int((elatency_relative + epoch_start * fs))
        end = int((elatency_relative + epoch_end * fs))
        if start > 0 and end < eeg_data.shape[1]:
            epochs.append(eeg_data[:, start:end])
            labels.append(etype)
    
    epochs = np.array(epochs)
    print(f"Extracted {len(epochs)} epochs for batch range ({batch_start}, {batch_end})")
    return epochs, labels

# Independent Component Analysis (ICA) for artifact removal
def apply_ica(epochs, fs, max_components=10, max_iter=300):
    info = create_info(ch_names=[f'EEG {i+1}' for i in range(epochs.shape[1])], sfreq=fs, ch_types='eeg')
    ica = ICA(n_components=max_components, random_state=42, max_iter=max_iter, verbose=False)
    epochs_highpass = bandpass_filter(epochs, lowcut=1.0, highcut=None, fs=fs)
    epochs_array = EpochsArray(epochs_highpass, info)
    ica.fit(epochs_array)
    print(f"Completed ICA.")
    return ica.apply(epochs_array).get_data()

# Time-Frequency Analysis (parallelized)
def time_frequency_analysis(epoch, sfreq=250, freqs=np.logspace(1, 2, 20)):
    n_channels = epoch.shape[0]
    info = create_info(ch_names=[f'EEG {i+1}' for i in range(n_channels)], sfreq=sfreq, ch_types='eeg')
    tfr = tfr_morlet(EpochsArray([epoch], info), freqs, n_cycles=2, return_itc=False)
    return tfr.data

def parallel_time_frequency_analysis(cleaned_epochs, sfreq=250, freqs=np.logspace(1, 2, 20), n_jobs=-1):
    """Perform parallelized time-frequency analysis."""
    power_chunks = Parallel(n_jobs=n_jobs)(
        delayed(time_frequency_analysis)(epoch, sfreq=sfreq, freqs=freqs) 
        for epoch in tqdm(cleaned_epochs, desc="Time-Frequency Analysis", leave=False)
    )
    return np.concatenate(power_chunks, axis=0)

# Save and load functions
def save_variables(output_dir, file_name, batch_num, **variables):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    save_path = os.path.join(output_dir, f"{file_name}_batch_{batch_num}.npz")
    np.savez_compressed(save_path, **variables)
    print(f"Saved variables for {file_name}, batch {batch_num} to {save_path}")

def load_variables(output_dir, file_name, batch_num):
    load_path = os.path.join(output_dir, f"{file_name}_batch_{batch_num}.npz")
    try:
        if os.path.exists(load_path):
            data = np.load(load_path)
            print(f"Loaded variables from {load_path}")
            return data
    except Exception as e:
        print(f"Error loading {load_path}: {e}")
    return None

def load_batch(file_path):
    """Helper function to load a single batch file."""
    try:
        batch_data = np.load(file_path)
        return {key: batch_data[key] for key in batch_data}
    except Exception as e:
        print(f"Error loading {file_path}: {e}")
        return None


# Process EEG files
def process_eeg_files_in_batches(file_list, base_dir, batch_size=5000, output_dir='processed_data/', start_batch=1):
    for file_name in tqdm(file_list, desc="Processing Files", leave=True):
        full_path = os.path.join(base_dir, file_name)
        print(f"Processing file: {file_name}")
        eeg_data, event_labels = load_and_preprocess_eeg(full_path)
        
        for i in tqdm(range(0, eeg_data.shape[1], batch_size), desc="Batch Progress", leave=False):
            batch_num = i // batch_size + 1
            
            # Skip already processed batches
            if batch_num < start_batch:
                continue
            
            batch_end = min(i + batch_size, eeg_data.shape[1])
            eeg_batch = eeg_data[:, i:batch_end]
            
            try:
                epochs, labels = epoch_eeg_data(eeg_batch, event_labels, i, batch_end)
                if epochs.size == 0:
                    print(f"No valid epochs in batch {batch_num}. Skipping...")
                    continue

                # Apply transformations
                cleaned_epochs = apply_ica(epochs, fs=250)
                power = parallel_time_frequency_analysis(cleaned_epochs)
                
                save_variables(output_dir, file_name, batch_num, epochs=epochs, cleaned_epochs=cleaned_epochs, power=power)

                # Memory cleanup
                del eeg_batch, epochs, cleaned_epochs, power
                gc.collect()
                
            except Exception as e:
                print(f"Error processing batch {batch_num}: {e}. Skipping to next.")

def load_batch_with_retry(file_path, max_retries=3, retry_delay=5):
    """Helper function to load a single batch file with retry logic."""
    retries = 0
    while retries < max_retries:
        try:
            batch_data = np.load(file_path)
            return {key: batch_data[key] for key in batch_data}
        except Exception as e:
            retries += 1
            print(f"Error loading {file_path} (Attempt {retries}/{max_retries}): {e}")
            time.sleep(retry_delay)
    return None

# Efficient batch loader for reduced memory usage
def load_all_saved_batches_in_chunks(output_dir, file_list, chunk_size=2, n_jobs=1):
    """Load saved batches in smaller chunks to manage memory, with retry logic for file access."""
    loaded_data = {}
    all_batch_files = [f for f in os.listdir(output_dir) if f.endswith(".npz")]
    
    for file_name in tqdm(file_list, desc="Loading Files", position=0, leave=True):
        relevant_files = [os.path.join(output_dir, f) for f in all_batch_files if f.startswith(file_name)]
        chunked_files = [relevant_files[i:i + chunk_size] for i in range(0, len(relevant_files), chunk_size)]
        
        loaded_batches = {}
        for chunk in tqdm(chunked_files, desc=f"Chunks for {file_name}", leave=False):
            batch_data = Parallel(n_jobs=n_jobs)(
                delayed(load_batch_with_retry)(file_path) for file_path in chunk
            )
            for f, data in zip(chunk, batch_data):
                if data is not None:
                    batch_num = int(f.split('_batch_')[1].split('.npz')[0])
                    loaded_batches[batch_num] = data

            # Memory Cleanup
            del batch_data
            gc.collect()
        
        loaded_data[file_name] = loaded_batches
    return loaded_data


# Main Execution
if rerun:
    # If rerun=True, process new data
    for category, file_list in tqdm([('Open Loop', open_loop_files)], desc="Processing Categories", leave=True):
        process_eeg_files_in_batches(file_list, base_dir, output_dir=output_dir)
else:
    # Load preprocessed data
    for category, file_list in tqdm([('Open Loop', open_loop_files)], desc="Loading Categories", leave=True):
        loaded_data = load_all_saved_batches_in_chunks(output_dir, file_list, chunk_size=2, n_jobs=-1)
        print(f"Loaded data for {category}: {loaded_data.keys()}")
# Out:
# Loading Files:   0%|                                      | 0/4 [00:00<?, ?it/s]
# Chunks for S01_B_RWEO_PreOL.mat:   0%|                    | 0/2 [00:00<?, ?it/s]
# Chunks for S01_B_RWEO_PreOL.mat:  50%|██████      | 1/2 [00:49<00:49, 49.35s/it]
# Chunks for S01_B_RWEO_PreOL.mat: 100%|████████████| 2/2 [02:07<00:00, 66.46s/it]
# Loading Files:  25%|███████▎                     | 1/4 [02:07<06:23, 127.79s/it]
# Chunks for S01_D_RWEO_PstOL.mat:   0%|                    | 0/2 [00:00<?, ?it/s]
# Chunks for S01_D_RWEO_PstOL.mat:  50%|██████      | 1/2 [00:20<00:20, 20.11s/it]
# Chunks for S01_D_RWEO_PstOL.mat: 100%|████████████| 2/2 [00:51<00:00, 26.79s/it]
# Loading Files:  50%|███████████████               | 2/4 [02:59<02:45, 82.96s/it]
# Chunks for S01_E_RWEO_PreCL.mat: 0it [00:00, ?it/s]
#
# Chunks for S01_G_RWEO_PstCL.mat: 0it [00:00, ?it/s]
# Loading Files: 100%|██████████████████████████████| 4/4 [02:59<00:00, 44.84s/it]
# Loading Categories:  33%|████████                | 1/3 [02:59<05:58, 179.38s/it]
# Loaded data for Baseline: dict_keys(['S01_B_RWEO_PreOL.mat', 'S01_D_RWEO_PstOL.mat', 'S01_E_RWEO_PreCL.mat', 'S01_G_RWEO_PstCL.mat'])
# Loading Files:   0%|                                      | 0/1 [00:00<?, ?it/s]
# Chunks for S01_C_OLoop.mat:   0%|                        | 0/14 [00:00<?, ?it/s]
# Chunks for S01_C_OLoop.mat:   7%|█              | 1/14 [02:29<32:24, 149.60s/it]
# Chunks for S01_C_OLoop.mat:  14%|██▏            | 2/14 [04:28<26:16, 131.37s/it]
# Chunks for S01_C_OLoop.mat:  21%|███▏           | 3/14 [07:36<28:50, 157.36s/it]
# Chunks for S01_C_OLoop.mat:  29%|████▎          | 4/14 [10:10<25:59, 155.98s/it]
# Chunks for S01_C_OLoop.mat:  36%|█████▎         | 5/14 [12:45<23:22, 155.81s/it]
# Chunks for S01_C_OLoop.mat:  43%|██████▍        | 6/14 [14:59<19:47, 148.42s/it]
# Chunks for S01_C_OLoop.mat:  50%|███████▌       | 7/14 [17:12<16:41, 143.14s/it]
# Chunks for S01_C_OLoop.mat:  57%|████████▌      | 8/14 [19:57<15:01, 150.24s/it]
# Chunks for S01_C_OLoop.mat:  64%|█████████▋     | 9/14 [22:26<12:29, 149.85s/it]
